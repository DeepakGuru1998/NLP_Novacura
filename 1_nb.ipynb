# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepakGuru1998/NLP_Novacura/blob/main/1_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd
import os
from datetime import datetime

def parse_date(date_string):
    """
    Parses a date string with various formats.

    Args:
        date_string (str): The date string to parse.

    Returns:
        datetime.date or None: The parsed date, or None if parsing fails.
    """
    date_formats = [
        "%Y-%m-%d",
        "%d-%m-%Y",
        "%m/%d/%Y",
        "%d/%m/%Y",
        "%d %b %Y",
        "%d %B %Y",
        "%dth %b %Y",
        "%dth %B %Y",
        "%d %b, %Y",
        "%d %B, %Y",
        "%dth %b, %Y",
        "%dth %B, %Y",
        "%b %d, %YYYY",
        "%B %d, %Y",
        "%b %d %Y",
        "%B %d %Y",
    ]

    for fmt in date_formats:
        try:
            return datetime.strptime(date_string, fmt).date()
        except ValueError:
            pass  # Try the next format

    return None

def extract_purchase_info(email_content):
    """
    Extracts purchase order information from email content, handling variations.

    Args:
        email_content (str): The content of the email.

    Returns:
        list: A list of dictionaries, where each dictionary represents a purchase order item.
    """

    items = []
    lines = email_content.split('\n')
    delivery_date = None

    # Extract delivery date if present
    for line in lines:
        date_match = re.search(r'(?:delivery date|delivery|date required|required date|ship date|expected delivery|arrive by|by)\s*(?:before|on|:)?\s*([a-zA-Z0-9\s,-]+)', line, re.IGNORECASE)
        if date_match:
            print(date_match.group())
            delivery_date = parse_date(date_match.group(1).strip())
            break

    for line in lines:
        # Refined regex to handle variations in item code formatting
        match = re.search(r'^\s*-?\s*(\d+)\s+units?\s+of\s+([\w\s-]+?)(?:\s*\(?Item Code:?\s*([-\w\d]+)\)?)?$', line, re.IGNORECASE)
        if match:
            units, product_name, item_code = match.groups()
            items.append({
                'units': int(units),
                'product_name': product_name.strip(),
                'item_code': item_code.strip() if item_code else None,  # Handle missing item codes
                'delivery_date': delivery_date
            })
        else:
            match = re.search(r'^(\d+)\s+([\w\s-]+?)(?:,\s*Item Code:?\s*([-\w\d]+))?$', line, re.IGNORECASE)
            if match:
                units, product_name, item_code = match.groups()
                items.append({
                    'units': int(units),
                    'product_name': product_name.strip(),
                    'item_code': item_code.strip() if item_code else None,
                    'delivery_date': delivery_date
                })

        #Handles erroneous duplicate orders.
        match_duplicate = re.search(r'^\s*-?\s*(\d+)\s+\d+\s+units?\s+of\s+([\w\s-]+?)(?:\s*\(?Item Code:?\s*([-\w\d]+)\)?)?$', line, re.IGNORECASE)
        if match_duplicate:
            units, product_name, item_code = match_duplicate.groups()
            items.append({
                'units': int(units),
                'product_name': product_name.strip(),
                'item_code': item_code.strip() if item_code else None,
                'delivery_date': delivery_date
            })

    return items

def process_emails_from_directory(directory):
    """
    Processes all email files in the given directory and creates a DataFrame.

    Args:
        directory (str): The path to the directory containing email files.

    Returns:
        pandas.DataFrame: A DataFrame containing purchase order information.
    """

    data = []
    for filename in os.listdir(directory):
        if filename.endswith(".txt") and "_PO_" in filename:
            file_path = os.path.join(directory, filename)
            try:
                with open(file_path, 'r') as file:
                    email_content = file.read()

                vendor_name = filename.split('_PO_')[0]
                po_number = filename.split('_PO_')[1].split('.')[0]

                items = extract_purchase_info(email_content)
                for item in items:
                    item['vendor_name'] = vendor_name
                    item['po_number'] = po_number
                    data.append(item)
            except FileNotFoundError:
                print(f"File not found: {file_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    return pd.DataFrame(data)

# Example Usage (replace 'your_directory' with the actual directory path)
directory = 'mail/'  # Current directory, change if needed
df = process_emails_from_directory(directory)
df
# Out:
# delivery by February 04, 2025
# by January 31, 2025
# delivery by February 03, 2025
# delivery by February 03, 2025
# by February 06, 2025
# Delivery by January 26, 2025 is required
# Expected delivery: February 03, 2025
# Expected delivery: February 02, 2025
# by February 05, 2025
# by February 11, 2025
# by February 09, 2025
# delivery by February 12, 2025
# Delivery by February 18, 2025 is required
# Delivery by February 09, 2025 is required
# Delivery by February 20, 2025 is required
# Delivery by January 26, 2025 is required
# Delivery by February 17, 2025 is required
# delivery by January 29, 2025
# Delivery by February 12, 2025 is required
# delivery by February 04, 2025
# Delivery by February 17, 2025 is required
# delivery by February 20, 2025
# Expected delivery: February 09, 2025
# delivery by January 26, 2025
# delivery by February 12, 2025
# Delivery by February 20, 2025 is required
# by February 18, 2025
# Expected delivery: February 09, 2025
# ...

# %%
df[df.delivery_date.notnull()]
# Out:
#      units      product_name item_code delivery_date           vendor_name  \
# 2      194    Motor Assembly   PC-1122    2025-01-31        Harris_Company
# 3      186     Control Valve   CB-3300    2025-01-31        Harris_Company
# 14     310    Heat Exchanger   BS-7890    2025-02-06  Robinson_Enterprises
# 22     243       Bearing Set   CV-6677    2025-02-03          Thomas_Group
# 23     402       Bearing Set   MA-2200    2025-02-03          Thomas_Group
# 24     201    Hydraulic Pump   CU-5643    2025-02-03          Thomas_Group
# 25     125   Compressor Unit   CV-6677    2025-02-02    Taylor_Enterprises
# 26     260    Heat Exchanger   PC-1122    2025-02-05        Rodriguez_Corp
# 28     375   Compressor Unit   PC-1122    2025-02-11          Thomas_Group
# 29     123    Motor Assembly   EP-9012    2025-02-11          Thomas_Group
# 30     217    Heat Exchanger   EP-9012    2025-02-11          Thomas_Group
# ...

# %%
df[df.vendor_name == 'Brown_Inc']
# Out:
#      units    product_name item_code delivery_date vendor_name po_number
# 48     299  Heat Exchanger   CV-6677          None   Brown_Inc        13
# 49     167  Heat Exchanger   PC-1122          None   Brown_Inc        13
# 50     230  Motor Assembly   HP-1001          None   Brown_Inc        13
# 59     135     Bearing Set   CV-6677          None   Brown_Inc        58
# 60     304     Bearing Set   HE-2345          None   Brown_Inc        58
# 62     299  Heat Exchanger   CV-6677          None   Brown_Inc        11
# 63     167  Heat Exchanger   PC-1122          None   Brown_Inc        11
# 64     230  Motor Assembly   HP-1001          None   Brown_Inc        11
# 103    264  Motor Assembly   CV-6677          None   Brown_Inc        50
# 108    355     Bearing Set   EP-9012    2025-02-18   Brown_Inc        55

# %%
# !pip install dateparser fuzzywuzzy
# !pip install spacy[transformers]
# !python -m spacy download en_core_web_trf

# %%
import os
import spacy
import pandas as pd
import dateparser
from pathlib import Path
from fuzzywuzzy import fuzz

nlp = spacy.load("en_core_web_trf")

def parse_po_line(line):
    doc = nlp(line)
    quantity = None
    product = None
    item_code = None

    for token in doc:
        if token.like_num and quantity is None:
            quantity = int(token.text)
        if token.text.lower() == "code":
            code_start = line.find("Item Code:")
            if code_start != -1:
                item_code = line[code_start + 10:].strip(" )\n")

    if "units of" in line:
        start = line.find("units of") + len("units of ")
        end = line.find("(") if "(" in line else len(line)
        product = line[start:end].strip()

    return quantity, product, item_code

def extract_delivery_date(lines):
    for line in lines:
        lower = line.lower()
        if "deliver" in lower or "delivery" in lower or "before" in lower or "by" in lower:
            doc = nlp(line)
            for ent in doc.ents:
                if ent.label_ == "DATE":
                    parsed_date = dateparser.parse(ent.text, settings={'PREFER_DATES_FROM': 'future'})
                    if parsed_date:
                        return parsed_date.date().isoformat()
    return ""

def parse_email(file_path):
    vendor_po = Path(file_path).stem
    vendor, po_num = vendor_po.split("_PO_")

    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()

    delivery_date = extract_delivery_date(lines)
    results = []

    for line in lines:
        if "units of" in line:
            units, product, code = parse_po_line(line)
            results.append({
                "vendor": vendor,
                "po_number": po_num,
                "product": product,
                "item_code": code,
                "units": units,
                "delivery_date_before": delivery_date
            })

    return results

def parse_all_emails(folder_path):
    all_rows = []
    for file in os.listdir(folder_path):
        if file.endswith(".txt") and "_PO_" in file:
            rows = parse_email(os.path.join(folder_path, file))
            all_rows.extend(rows)
    return pd.DataFrame(all_rows)
df = parse_all_emails("mail/")
# Out:
# Smith_Corp_PO_14.txt
# Rodriguez_Corp_PO_02.txt
# Harris_Company_PO_26.txt
# Young_Group_PO_57.txt
# Lewis_Supplies_PO_17.txt
# Allen_Consulting_PO_27.txt
# Garcia_Services_PO_56.txt
# Taylor_Enterprises_PO_48.txt
# Robinson_Enterprises_PO_21.txt
# Martin_Solutions_PO_42.txt
# Martin_Solutions_PO_53.txt
# Smith_Corp_PO_05.txt
# Garcia_Services_PO_07.txt
# Thomas_Group_PO_15.txt
# Taylor_Enterprises_PO_45.txt
# Rodriguez_Corp_PO_60.txt
# Thomas_Group_PO_36.txt
# Thomas_Group_PO_03.txt
# Lewis_Supplies_PO_06.txt
# Martinez_LLC_PO_54.txt
# Young_Group_PO_44.txt
# Martinez_LLC_PO_01.txt
# Allen_Consulting_PO_12.txt
# Harris_Company_PO_46.txt
# Martin_Solutions_PO_34.txt
# Young_Group_PO_31.txt
# Martinez_LLC_PO_33.txt
# Brown_Inc_PO_13.txt
# Thomas_Group_PO_20.txt
# Walker_Enterprises_PO_24.txt
# Anderson_Industries_PO_52.txt
# Brown_Inc_PO_58.txt
# Smith_Corp_PO_51.txt
# Brown_Inc_PO_11.txt
# Walker_Enterprises_PO_10.txt
# Walker_Enterprises_PO_25.txt
# Taylor_Enterprises_PO_59.txt
# ...

# %%
df.sort_values(by=['vendor','po_number'])
# Out:
#                   vendor po_number             product item_code  units  \
# 41      Allen_Consulting        12  Pneumatic Cylinder   MA-2200    197
# 42      Allen_Consulting        12     Compressor Unit   MA-2200    322
# 43      Allen_Consulting        12      Hydraulic Pump   CU-5643    298
# 9       Allen_Consulting        27      Hydraulic Pump   MA-2200    321
# 101  Anderson_Industries        09  Pneumatic Cylinder   PC-1122    270
# ..                   ...       ...                 ...       ...    ...
# 37           Young_Group        44        Gear Reducer   CB-3300     30
# 38           Young_Group        44      Hydraulic Pump   MA-2200    419
# 39           Young_Group        44      Motor Assembly   BS-7890    484
# 4            Young_Group        57       Conveyor Belt   CU-5643    470
# 5            Young_Group        57      Motor Assembly   CU-5643    176
#
#     delivery_date_before
# 41            2025-02-09
# 42            2025-02-09
# ...

# %%
import os
import pandas as pd
import spacy
import dateparser

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Folder with your email .txt files
EMAIL_DIR = "mail/"
records = []

def extract_info(text, vendor_name, po_number):
    doc = nlp(text)
    current_item = {
        "vendor": vendor_name,
        "po_number": po_number,
        "units": None,
        "product_name": None,
        "item_code": None,
        "delivery_date": None
    }

    for sent in doc.sents:
        tokens = list(sent)
        # Simple way to catch product lines like "100 units of XYZ (Item Code: XYZ-123)"
        for i, token in enumerate(tokens):
            if token.like_num and "unit" in tokens[i+1].text.lower():
                current_item["units"] = int(token.text)
                # Get product name
                name_tokens = []
                j = i + 3  # skip "of"
                while j < len(tokens) and tokens[j].is_alpha:
                    name_tokens.append(tokens[j].text)
                    j += 1
                current_item["product_name"] = " ".join(name_tokens)

        # Item code pattern using spaCy (not regex)
        for i, token in enumerate(tokens):
            if token.text.lower() == "code":
                if i + 2 < len(tokens) and tokens[i+1].text in [":", "-", "is"]:
                    current_item["item_code"] = tokens[i+2].text.strip(").,")
                elif i + 1 < len(tokens):
                    current_item["item_code"] = tokens[i+1].text.strip(").,")

        # Try parsing delivery date
        date = dateparser.parse(sent.text, settings={'PREFER_DATES_FROM': 'future'})
        if date:
            current_item["delivery_date"] = date.date()

        # Store only complete lines with product name
        if current_item["product_name"]:
            records.append(current_item.copy())
            current_item["product_name"] = None  # reset for next item

# Go through all .txt files
for file in os.listdir(EMAIL_DIR):
    if file.endswith(".txt"):
        filepath = os.path.join(EMAIL_DIR, file)
        with open(filepath, "r", encoding="utf-8") as f:
            text = f.read()
            # Extract vendor and PO from filename
            name = os.path.splitext(file)[0]
            if "_PO_" in name:
                vendor, po = name.split("_PO_")
            else:
                vendor, po = name, ""
            extract_info(text, vendor, po)

# Save to Excel
df = pd.DataFrame(records)
#df.to_excel("purchase_orders.xlsx", index=False)
print("✅ Extraction complete. Data saved to 'purchase_orders.xlsx'.")
df.sort_values(by=['vendor','po_number'])
# Out:
# ✅ Extraction complete. Data saved to 'purchase_orders.xlsx'.
#                  vendor po_number  units      product_name item_code  \
# 22     Allen_Consulting        12    298    Hydraulic Pump   CU-5643
# 5      Allen_Consulting        27    321    Hydraulic Pump   MA-2200
# 50  Anderson_Industries        09    446      Gear Reducer   MA-2200
# 61  Anderson_Industries        22     73      Gear Reducer   CB-3300
# 31  Anderson_Industries        52    439    Heat Exchanger   GR-4500
# ..                  ...       ...    ...               ...       ...
# 25          Young_Group        31    235   Compressor Unit   PC-1122
# 46          Young_Group        35    409  Electrical Panel   CB-3300
# 44          Young_Group        37    484    Motor Assembly   BS-7890
# 20          Young_Group        44    484    Motor Assembly   BS-7890
# 3           Young_Group        57    176    Motor Assembly   CU-5643
#
#    delivery_date
# 22          None
# 5           None
# 50          None
# ...
